# %%
import pandas as pd
pd.set_option('display.max_rows',500)
pd.set_option('display.max_columns',500)
pd.set_option('display.width',500)
import numpy as np
ecom= pd.read_excel(r'D:\IDM DOWNLOADS\EcommerceAnalytics\E-com_Data.xlsx')

# %%
ecom.head(100)
# Out:
#     CustomerID Item Code  InvoieNo Date of purchase  Quantity      Time  price per Unit    Price Shipping Location  Cancelled_status Reason of return  Sold as set
# 0       4355.0     15734    398177       2017-10-29         6  15:36:00           321.0   1926.0        Location 1               NaN              NaN          NaN
# 1       4352.0     14616    394422       2017-10-05         2  14:53:00           870.0   1740.0        Location 1               NaN              NaN          NaN
# 2       4352.0     14614    394422       2017-10-12         2  14:53:00           933.0   1866.0        Location 1               NaN              NaN          NaN
# 3       4352.0    85014B    388633       2017-08-22         3  14:47:00           623.0   1869.0        Location 1               NaN              NaN          NaN
# 4       4352.0     15364    394422       2017-10-10         2  14:53:00           944.0   1888.0        Location 1               NaN              NaN          NaN
# ...

# %%
ecom1 = ecom.iloc[:,[0,1,2,3,7,8]]

# %%
ecom1.head()
# Out:
#    CustomerID Item Code  InvoieNo Date of purchase   Price Shipping Location
# 0      4355.0     15734    398177       2017-10-29  1926.0        Location 1
# 1      4352.0     14616    394422       2017-10-05  1740.0        Location 1
# 2      4352.0     14614    394422       2017-10-12  1866.0        Location 1
# 3      4352.0    85014B    388633       2017-08-22  1869.0        Location 1
# 4      4352.0     15364    394422       2017-10-10  1888.0        Location 1

# %%
ecom1.nunique(0,dropna=False)
# Out:
# CustomerID            4350
# Item Code             4009
# InvoieNo             24928
# Date of purchase       381
# Price                16327
# Shipping Location       20
# dtype: int64

# %%
ecom1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537979 entries, 0 to 537978
# Data columns (total 6 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CustomerID         404189 non-null  float64
#  1   Item Code          537979 non-null  object
#  2   InvoieNo           537979 non-null  int64
#  3   Date of purchase   537979 non-null  datetime64[ns]
#  4   Price              537979 non-null  float64
#  5   Shipping Location  537979 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(2)
# memory usage: 24.6+ MB

# %%
ecom_new =ecom1.dropna()

# %%
ecom_new.head(34)
# Out:
#     CustomerID Item Code  InvoieNo Date of purchase    Price Shipping Location
# 0       4355.0     15734    398177       2017-10-29   1926.0        Location 1
# 1       4352.0     14616    394422       2017-10-05   1740.0        Location 1
# 2       4352.0     14614    394422       2017-10-12   1866.0        Location 1
# 3       4352.0    85014B    388633       2017-08-22   1869.0        Location 1
# 4       4352.0     15364    394422       2017-10-10   1888.0        Location 1
# 5       4349.0     14618    397122       2017-10-27    256.0        Location 1
# 6       4343.0     15364    368432       2017-02-13  -3688.0        Location 1
# 7       4341.0    85014B    377109       2017-05-14   2031.0        Location 1
# 8       4341.0    85014A    377109       2017-05-12   2076.0        Location 1
# 9       4341.0    85014B    390217       2017-09-07   4020.0        Location 1
# 10      4341.0    85014B    389462       2017-09-04   4044.0        Location 1
# ...

# %%
ecom_new = ecom_new.astype({'CustomerID':int})

# %%
ecom_new.head(45)
# Out:
#     CustomerID Item Code  InvoieNo Date of purchase    Price Shipping Location
# 0         4355     15734    398177       2017-10-29   1926.0        Location 1
# 1         4352     14616    394422       2017-10-05   1740.0        Location 1
# 2         4352     14614    394422       2017-10-12   1866.0        Location 1
# 3         4352    85014B    388633       2017-08-22   1869.0        Location 1
# 4         4352     15364    394422       2017-10-10   1888.0        Location 1
# 5         4349     14618    397122       2017-10-27    256.0        Location 1
# 6         4343     15364    368432       2017-02-13  -3688.0        Location 1
# 7         4341    85014B    377109       2017-05-14   2031.0        Location 1
# 8         4341    85014A    377109       2017-05-12   2076.0        Location 1
# 9         4341    85014B    390217       2017-09-07   4020.0        Location 1
# 10        4341    85014B    389462       2017-09-04   4044.0        Location 1
# ...

# %%
ecom_new.rename(columns={'Shipping Location':'Shipping_location'},inplace=True)

# %%
ecom_new.columns
# Out:
# Index(['CustomerID', 'Item Code', 'InvoieNo', 'Date of purchase', 'Price', 'Shipping_location'], dtype='object')

# %%
ecom_new.Shipping_location.value_counts()
# Out:
# Location 36    376353
# Location 14      8316
# Location 26      6981
# Location 15      4265
# Location 1       2925
# Location 11      2257
# Location 37       744
# Location 25       586
# Location 21       517
# Location 20       403
# Location 4        174
# Location 23       172
# Location 32       132
# Location 8        111
# Location 28       103
# Location 10        95
# Location 31        33
# Location 7         18
# Location 34         2
# Location 24         2
# Name: Shipping_location, dtype: int64

# %%
ecom_final = ecom_new[ecom_new.Shipping_location == 'Location 36']

# %%
ecom_final.shape
# Out:
# (376353, 6)

# %%
ecom_final.isnull().sum()
# Out:
# CustomerID           0
# Item Code            0
# InvoieNo             0
# Date of purchase     0
# Price                0
# Shipping_location    0
# dtype: int64

# %%
ecom_final.drop_duplicates(keep='first',inplace=True)
# Out:
# <ipython-input-60-17ff40b6f525>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ecom_final.drop_duplicates(keep='first',inplace=True)

# %%
ecom_final.Price.max()
# Out:
# 90400.00000000001

# %%
ecom1.CustomerID.fillna(0,inplace=True)
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\pandas\core\series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
ecom1[ecom1.CustomerID == 0].groupby('InvoieNo')['CustomerID'].count()
# Out:
# InvoieNo
# 361478      1
# 361608    526
# 361609      1
# 361610      1
# 361611      1
#          ...
# 406499      2
# 406503    634
# 406556    730
# 406561     59
# 406562    217
# Name: CustomerID, Length: 3337, dtype: int64

# %%
ecom_final.InvoieNo.dtype
# Out:
# dtype('int64')

# %%
ecom1[ecom1.CustomerID == 0].Price.sum()
# Out:
# 162788208.0

# %%
a=ecom1[ecom1.CustomerID == 0].groupby('InvoieNo')['Price'].sum()

# %%
a.max()
# Out:
# 3151779.0

# %%
ecom_final.head()
# Out:
#    CustomerID Item Code  InvoieNo Date of purchase   Price
# 0        4372     39845    395779       2017-10-14  1080.0
# 1        4372     15178    379129       2017-06-01  1104.0
# 2        4372     15177    379129       2017-05-25  1176.0
# 3        4372     14844    395779       2017-10-17  1272.0
# 4        4372     15801    395779       2017-10-15  1272.0

# %%
ecom_final.drop(['index'],inplace=True,axis=1)
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
ecom_final.drop(['Shipping_location'],inplace=True,axis=1)
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
ecom_final.rename(columns={'Date of purchase':'date_of_purchase','InvoieNo':'invoiceno'},inplace=True)
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
ecom_final['Price'] =ecom_final[(ecom_final['Price'] >0)]
# Out:
# <ipython-input-184-f52f37246ad0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ecom_final['Price'] =ecom_final[(ecom_final['Price'] >0)]

# %%
ecom_final.Price.min()
# Out:
# 2.0

# %%
ecom_final.groupby('invoiceno')['CustomerID'].aggregate('count').reset_index().sort_values('CustomerID',ascending=False)
# Out:
#        invoiceno  CustomerID
# 18800     401403         506
# 20202     404260         495
# 20939     405791         488
# 19787     403334         409
# 17471     398640         402
# ...          ...         ...
# 19092     401986           1
# 9397      381740           1
# 9402      381748           1
# 14630     392864           1
# 15016     393604           1
#
# [21364 rows x 2 columns]

# %%
ecom[ecom.InvoieNo==404260].isnull().sum()
# Out:
# CustomerID             0
# Item Code              0
# InvoieNo               0
# Date of purchase       0
# Quantity               0
# Time                   0
# price per Unit         0
# Price                  0
# Shipping Location      0
# Cancelled_status     532
# Reason of return     532
# Sold as set          532
# dtype: int64

# %%
import datetime as dt

# %%
ecom_final.date_of_purchase.max()
# Out:
# Timestamp('2017-12-19 00:00:00')

# %%
ecom_final.date_of_purchase.min()
# Out:
# Timestamp('2016-12-02 00:00:00')

# %%
recency_date=dt.datetime(2017,12,19)

# %%
r=ecom_final.groupby('CustomerID',as_index=False).agg({'date_of_purchase': lambda x:(recency_date -x.max()).days})

# %%
m=ecom_final.groupby('CustomerID',as_index=False).agg({'Price' : lambda x :(x.max())})

# %%
f=ecom_final.groupby('CustomerID',as_index=False).agg({'invoiceno': lambda x :(round(x.count()/2))})

# %%
f
# Out:
#       CustomerID  invoiceno
# 0              2         74
# 1              3         12
# 2              4         32
# 3              5          8
# 4              6         40
# ...          ...        ...
# 4342        4368          4
# 4343        4369          4
# 4344        4370          6
# 4345        4371        344
# 4346        4372         34
#
# [4347 rows x 2 columns]

# %%
m.drop('CustomerID',axis=1,inplace=True)

# %%
f.drop('CustomerID',axis=1,inplace=True)

# %%
rmf_scores=pd.concat([r,f,m],axis=1)

# %%
rmf_scores.describe()
# Out:
#         CustomerID  date_of_purchase    invoiceno        Price
# count  4347.000000       4347.000000  4347.000000  4322.000000
# mean   2186.350587         92.505176    43.278583  2184.598565
# std    1261.302293        100.829325   107.788167  1261.349966
# min       2.000000          0.000000     0.000000     2.000000
# 25%    1094.500000         17.000000     8.000000  1092.250000
# 50%    2185.000000         50.000000    20.000000  2181.500000
# 75%    3278.500000        143.500000    48.000000  3278.750000
# max    4372.000000        380.000000  3691.000000  4372.000000

# %%
rmf_scores.columns =['CustomerID','Recency','Frequency','Monetary']

# %%
rmf_scores.head()
# Out:
#    CustomerID  Recency  Frequency  Monetary r_quartile f_quartile m_quartile  rmf
# 0           2        3         74       2.0          4          4          1  441
# 1           3       76         12       3.0          2          2          1  221
# 2           4       18         32       4.0          3          3          1  331
# 3           5      310          8       5.0          1          1          1  111
# 4           6       36         40       6.0          3          3          1  331

# %%
rmf_scores['r_quartile'] = pd.qcut(rmf_scores['Recency'], 4, ['4','3','2','1'])
rmf_scores['f_quartile'] = pd.qcut(rmf_scores['Frequency'], 4, ['1','2','3','4'])
rmf_scores['m_quartile'] = pd.qcut(rmf_scores['Monetary'], 4, ['1','2','3','4'])

# %%
rmf_scores['rmf'] =rmf_scores.r_quartile.astype(str)+ rmf_scores.f_quartile.astype(str) + rmf_scores.m_quartile.astype(str)

# %%
rmf_scores.drop('rfmscore',axis=1,inplace=True)

# %%
rmf_scores=rmf_scores.astype({'r_quartile':'int64'})

# %%
rmf_scores=rmf_scores.astype({'f_quartile':'int64'})

# %%
rmf_scores=rmf_scores.dropna()

# %%
rmf_scores=rmf_scores.astype({'m_quartile':'int64'})

# %%
rmf_scores['rfmscore'] =rmf_scores[['r_quartile','f_quartile','m_quartile']].sum(axis=1)

# %%
rmf_scores.shape
# Out:
# (4322, 9)

# %%
rmf_scores.rfmscore.value_counts()
# Out:
# 7     678
# 8     621
# 6     619
# 9     616
# 5     487
# 10    448
# 11    296
# 4     294
# 12    135
# 3     128
# Name: rfmscore, dtype: int64

# %%
loyalty=['bronze','silver','gold','platinum']
rmf_scores['loyalty_level']=pd.qcut(rmf_scores['rfmscore'],4,labels=loyalty)

# %%
rmf_scores=rmf_scores.sort_values('rfmscore').reset_index()

# %%
rmf_scores.head(500)
# Out:
#      index  CustomerID  Recency  Frequency  Monetary  r_quartile  f_quartile  m_quartile  rmf  rfmscore loyalty_level
# 0      361         366      172          2     366.0           1           1           1  111         3        bronze
# 1     1052        1060      205          6    1060.0           1           1           1  111         3        bronze
# 2      370         375      283          2     375.0           1           1           1  111         3        bronze
# 3      371         376      182          8     376.0           1           1           1  111         3        bronze
# 4      373         378      215          3     378.0           1           1           1  111         3        bronze
# 5      826         834      165          8     834.0           1           1           1  111         3        bronze
# 6     1045        1053      151          6    1053.0           1           1           1  111         3        bronze
# ...
